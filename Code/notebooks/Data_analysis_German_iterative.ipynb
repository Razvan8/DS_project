# %%
import sys
# %load_ext autoreload
# %autoreload 2

sys.path.append("../libs/")
from data_prep import *
from bias_pipeline import *

# %%
X,y=load_data()


##Tests 
def test1(value):
    if value>=35:
        return 1
    else:
        return 0
def test2(value):
    if value <30 or value>60:
        return 1
    else:
        return 0
###

##Replace with binary for age and make ycolumn: 0 or 1
X=replace_values_with_binary(X,"Attribute9",["A91","A93","A94"])# transform Attribute9 it into gender column

y=replace_values_with_binary(y,y.columns[0],[1])# transform y to col with 0/1 values with 0:bad  1:good 
print(y)

X=apply_function_to_column(df=X,column_name="Attribute13",test_function=test1, new_name="Age_group")

create_iterative_german_bias(X=X, unprivileged_class_name1="Age_group", unprivileged_class_name2= "Attribute9", unprivileged_class_value1=0, unprivileged_class_value2=0,
                           y=y, p_range1=[0.2,0.5,0.8], p_range2=[0.2,0.5,0.8], verbose=True, dataset_name =  'German_credit_biased')
# Out:
# Data loaded successfully
#      class
# 0        1
# 1        0
# 2        1
# 3        1
# 4        0
# ..     ...
# 995      1
# 996      1
# 997      1
# 998      0
# 999      1
#
# [1000 rows x 1 columns]
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 9.295774647887324% .
# No of posiitve samples of unprivileged class kept is 66, this means 18.53932584269663 % . It should be close to 71.2
# Initial positive percentage of samples from unprivileged class is 14.507042253521126 % .
# Current percentage of samples from positive unprivileged class is 3.4976152623211445% .
# No of posiitve samples of unprivileged class kept is 22, this means 21.35922330097087 % . It should be close to 20.6
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 10.679611650485436% .
# No of posiitve samples of unprivileged class kept is 77, this means 21.629213483146067 % . It should be close to 71.2
# Initial positive percentage of samples from unprivileged class is 14.701803051317613 % .
# Current percentage of samples from positive unprivileged class is 8.482142857142858% .
# No of posiitve samples of unprivileged class kept is 57, this means 53.77358490566038 % . It should be close to 53.0
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 10.43115438108484% .
# No of posiitve samples of unprivileged class kept is 75, this means 21.06741573033708 % . It should be close to 71.2
# Initial positive percentage of samples from unprivileged class is 14.603616133518777 % .
# Current percentage of samples from positive unprivileged class is 12.784090909090908% .
# No of posiitve samples of unprivileged class kept is 90, this means 85.71428571428571 % . It should be close to 84.0
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 21.74969623329283% .
# No of posiitve samples of unprivileged class kept is 179, this means 50.28089887640449 % . It should be close to 178.0
# Initial positive percentage of samples from unprivileged class is 17.618469015795867 % .
# Current percentage of samples from positive unprivileged class is 3.1428571428571432% .
# No of posiitve samples of unprivileged class kept is 22, this means 15.172413793103448 % . It should be close to 29.0
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 21.271393643031786% .
# No of posiitve samples of unprivileged class kept is 174, this means 48.87640449438202 % . It should be close to 178.0
# Initial positive percentage of samples from unprivileged class is 16.625916870415647 % .
# Current percentage of samples from positive unprivileged class is 8.945260347129507% .
# No of posiitve samples of unprivileged class kept is 67, this means 49.26470588235294 % . It should be close to 68.0
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 22.596153846153847% .
# No of posiitve samples of unprivileged class kept is 188, this means 52.80898876404494 % . It should be close to 178.0
# Initial positive percentage of samples from unprivileged class is 16.58653846153846 % .
# Current percentage of samples from positive unprivileged class is 13.25% .
# No of posiitve samples of unprivileged class kept is 106, this means 76.81159420289855 % . It should be close to 110.4
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 30.37837837837838% .
# No of posiitve samples of unprivileged class kept is 281, this means 78.93258426966293 % . It should be close to 284.8
# Initial positive percentage of samples from unprivileged class is 18.27027027027027 % .
# Current percentage of samples from positive unprivileged class is 4.424778761061947% .
# No of posiitve samples of unprivileged class kept is 35, this means 20.710059171597635 % . It should be close to 33.800000000000004
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 30.82706766917293% .
# No of posiitve samples of unprivileged class kept is 287, this means 80.6179775280899 % . It should be close to 284.8
# Initial positive percentage of samples from unprivileged class is 18.904403866809883 % .
# Current percentage of samples from positive unprivileged class is 9.36374549819928% .
# No of posiitve samples of unprivileged class kept is 78, this means 44.31818181818182 % . It should be close to 88.0
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 31.70731707317073% .
# No of posiitve samples of unprivileged class kept is 299, this means 83.98876404494382 % . It should be close to 284.8
# Initial positive percentage of samples from unprivileged class is 19.088016967126194 % .
# Current percentage of samples from positive unprivileged class is 15.87651598676957% .
# No of posiitve samples of unprivileged class kept is 144, this means 80.0 % . It should be close to 144.0
# Dataframes saved in their directory from 'Dataframes' directory.

# %% [markdown]
# # CONTINUA CU MODELS ITERATIVE #####
